# %%
# %run Functions.ipynb
Valve_R = 32.5 #pipe radius
PMT_R = 12.5 #pmt radius
L_cone = 50 #length of cone
L_cavity = 80 #length of cavity
L_semi = L_cone+L_cavity/2 #semi-length between pmts
constants = [Valve_R,PMT_R,L_cone,L_cavity,L_semi]
t1 = time.time()
plot_surfaces(nt=25,random_regions=[],mesh_regions=[1,2,3,4],constants=constants)
t2 = time.time()
print("time: %d[min],%1.1f[s]"%(int((t2-t1)/60),(t2-t1)%60))
# Out:
# time: 0[min],0.8[s]

# %%
# %run Functions.ipynb
t1 = time.time()
plot_surfaces(nt=50000,random_regions=[1,2,3,4],mesh_regions=[])
t2 = time.time()
print("time: %d[min],%1.1f[s]"%(int((t2-t1)/60),(t2-t1)%60))
# Out:
# time: 0[min],2.2[s]

# %%
numbers = [10,100,1000,5000,10000,50000,100000,500000,1000000,5000000,10000000]
montecarlo_random_gamma(numbers,plot=True,progress=True,save=[True,"Random_Montecarlo_1gamma"])
numbers = [4,5,8,10,12,15,20,23,25,28,30]
montecarlo_mesh_gamma(numbers,plot=True,progress=True,save=[True,"Meshed_Montecarlo_1gamma"])
# Out:
# Running n[11 of 11] = 10000000, percentage: 100 %
# time: 9[min],51.2[s]
# Running n[11 of 11] = 30, percentage: 100 %
# time: 11[min],24.5[s]
# (0.03896282061544163, 0.03895658027668827)

# %%
# %run Functions.ipynb
Valve_R = 32.5/2 #pipe radius !!!!!!!!!!!!!!!
PMT_R = 12.5 #pmt radius
L_cone = 50/2 #length of cone !!!!!!!!!!!!!!!!
L_cavity = 80 #length of cavity
L_semi = L_cone+L_cavity/2 #semi-length between pmts
constants = [Valve_R,PMT_R,L_cone,L_cavity,L_semi]
t1 = time.time()
plot_surfaces(nt=5000,mesh_regions=[],random_regions=[1,2,3,4],constants=constants)
t2 = time.time()
print("time: %d[min],%1.1f[s]"%(int((t2-t1)/60),(t2-t1)%60))
numbers = [10,100,1000,5000,10000,50000,100000,500000]#,1000000]#,5000000,10000000]
montecarlo_random_gamma(numbers,constants,plot=True,progress=True,save=[True,"Random_Montecarlo_1gamma"])
print(" ")
numbers = [4,5,8,10,12,15,20,23,25]#,28,30]
montecarlo_mesh_gamma(numbers,constants,plot=True,progress=True,save=[True,"Meshed_Montecarlo_1gamma"])
# Out:
# time: 0[min],0.4[s]
# Running n[8 of 8] = 500000, percentage: 100 %
# time: 0[min],20.3[s]
#
# Running n[9 of 9] = 25, percentage: 100 %
# time: 3[min],24.7[s]
# (0.020873638430013136, 0.020873638430013136)

# %%
Valve_R = 32.5 #pipe radius
PMT_R = 12.5 #pmt radius
L_cone = 50*2 #length of cone !!! 
L_cavity = 80 #length of cavity
L_semi = L_cone+L_cavity/2 #semi-length between pmts
constants = [Valve_R,PMT_R,L_cone,L_cavity,L_semi]
t1 = time.time()
plot_surfaces(nt=5000,mesh_regions=[],random_regions=[1,2,3,4],constants=constants)
t2 = time.time()
print("time: %d[min],%1.1f[s]"%(int((t2-t1)/60),(t2-t1)%60))
numbers = [10,100,1000,5000,10000,50000,100000,500000,1000000,5000000]#,10000000]
montecarlo_random_gamma(numbers,constants,plot=True,progress=True,save=[True,"Random_Montecarlo_1gamma"])
print(" ")
numbers = [4,5,8,10,12,15,20,23,25,28]#,30]
montecarlo_mesh_gamma(numbers,constants,plot=True,progress=True,save=[True,"Meshed_Montecarlo_1gamma"])
# Out:
# time: 0[min],6.1[s]
# Running n[10 of 10] = 5000000, percentage: 100 %
# time: 3[min],19.1[s]
#
# Running n[10 of 10] = 28, percentage: 100 %
# time: 6[min],16.4[s]
# (0.03942978007747059, 0.03942895430035704)

# %%
Valve_R = 32.5 #pipe radius
PMT_R = 12.5 #pmt radius
L_cone = 50 #length of cone !!! 
L_cavity = 80*2 #length of cavity
L_semi = L_cone+L_cavity/2 #semi-length between pmts
constants = [Valve_R,PMT_R,L_cone,L_cavity,L_semi]
t1 = time.time()
plot_surfaces(nt=5000,mesh_regions=[],random_regions=[1,2,3,4],constants=constants)
t2 = time.time()
print("time: %d[min],%1.1f[s]"%(int((t2-t1)/60),(t2-t1)%60))
numbers = [10,100,1000,5000,10000,50000,100000,500000,1000000,5000000]#,10000000]
montecarlo_random_gamma(numbers,constants,plot=True,progress=True,save=[True,"Random_Montecarlo_1gamma"])
print(" ")
numbers = [4,5,8,10,12,15,20,23,25,28]#,30]
montecarlo_mesh_gamma(numbers,constants,plot=True,progress=True,save=[True,"Meshed_Montecarlo_1gamma"])
# Out:
# time: 0[min],0.7[s]
# Running n[10 of 10] = 5000000, percentage: 100 %
# time: 3[min],32.3[s]
#
# Running n[10 of 10] = 28, percentage: 100 %
# time: 6[min],37.5[s]
# (0.05246790311660649, 0.052473360426226474)

# %%
Valve_R = 32.5 #pipe radius
PMT_R = 12.5 #pmt radius
L_cone = 50/2 #length of cone !!! 
L_cavity = 80*2 #length of cavity
L_semi = L_cone+L_cavity/2 #semi-length between pmts
constants = [Valve_R,PMT_R,L_cone,L_cavity,L_semi]
t1 = time.time()
plot_surfaces(nt=5000,mesh_regions=[],random_regions=[1,2,3,4],constants=constants)
t2 = time.time()
print("time: %d[min],%1.1f[s]"%(int((t2-t1)/60),(t2-t1)%60))
numbers = [10,100,1000,5000,10000,50000,100000,500000,1000000,5000000]#,10000000]
montecarlo_random_gamma(numbers,constants,plot=True,progress=True,save=[True,"Random_Montecarlo_1gamma"])
print(" ")
numbers = [4,5,8,10,12,15,20,23,25,28]#,30]
montecarlo_mesh_gamma(numbers,constants,plot=True,progress=True,save=[True,"Meshed_Montecarlo_1gamma"])
# Out:
# time: 0[min],0.4[s]
# Running n[10 of 10] = 5000000, percentage: 100 %
# time: 3[min],32.4[s]
#
# Running n[10 of 10] = 28, percentage: 100 %
# time: 6[min],18.5[s]
# (0.07952061267997483, 0.07951537079047143)
